# %% [markdown]
# ### Introduction To Pandas Module
# Here, we are learning data analysis. Pandas is a software library written for the Python programming language that helps with data manipulation and analysis. It offers various data structures which help in the manipulation of data. <br>
# One of the data structures used is DataFrame.<br>
# DataFrame is used as a way to store data in a rectangular grid.<br>
# Similar to how data is stored in Microsoft Excel.
# ### Installation
# We can easily install this library using the terminal. Follow the steps given below to install Pandas:<br>
# Step 1: Go to the Windows PowerShell.<br>
# Step 2: We can install pandas with the help of pip easily. Head over to the directory where you want to install the pandas and fire the below command:<br>
# __pip install pandas__<br>
# This is very simple to install.

# %% [markdown]
# ### Other way to install
# If the above steps do not work for you, here is another way to install:<br>
# Step 1: Go to your browser. Search for __python unofficial binaries__, or click <br>
# https://www.lfd.uci.edu/~gohlke/pythonlibs/<br>
# and you will be redirected to the binary page.<br>
# Step 2: To download the library, search for pandas – Ctrl + F will help you. Download pandas library based on your python version. <br>
# Step 3: After the installation, head over to the directory where you've downloaded the pandas. <br>
# Step 4: Right-click to open Windows PowerShell. Pip can help us with the installation. Just go to that location in your terminal and run the following command: <br>
# __pip install pandas__ <br>
# Complete this command by the TAB button so that the location of your folder is mentioned.

# %% [markdown]
# ### import pandas
# Once Pandas is installed, import it in your applications by adding the import keyword:<br>
# __import pandas as pd__<br>
# Now Pandas is imported and ready to use.

# %%
import pandas as pd

# %%
dict1 = {
    'Name': ["Ahmed Khan", "Fatima Noor", "Mohammad Ali", "Ayesha Siddiq",
             "Hassan Raza","Zainab Sheikh","Umar Farooq","Maryam Bibi",
             "Bilal Saeed","Khadija Rehman","Yusuf Jamal","Hafsa Tariq",
             "Ibrahim Zaid","Nimra Shah","Suleman Iqbal"],


    'Registration Number': ["21jzele04230","21jzele04231","21jzele04232","21jzele04233","21jzele04234",
                             "21jzele04235","21jzele04236","21jzele04237","21jzele04238","21jzele04239",
                             "21jzele04240","21jzele04241","21jzele04242","21jzele04243","21jzele04244"],


    'GPA':["3.22","2.15","2.74","3.34","2.8","2.6","3.61","3.25","2.14","2.15","2.01","2.33",
           "2.15","2.07","3.3"]
}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#               Name Registration Number   GPA
# 0       Ahmed Khan        21jzele04230  3.22
# 1      Fatima Noor        21jzele04231  2.15
# 2     Mohammad Ali        21jzele04232  2.74
# 3    Ayesha Siddiq        21jzele04233  3.34
# 4      Hassan Raza        21jzele04234   2.8
# 5    Zainab Sheikh        21jzele04235   2.6
# 6      Umar Farooq        21jzele04236  3.61
# 7      Maryam Bibi        21jzele04237  3.25
# 8      Bilal Saeed        21jzele04238  2.14
# 9   Khadija Rehman        21jzele04239  2.15
# 10     Yusuf Jamal        21jzele04240  2.01
# 11     Hafsa Tariq        21jzele04241  2.33
# 12    Ibrahim Zaid        21jzele04242  2.15
# 13      Nimra Shah        21jzele04243  2.07
# 14   Suleman Iqbal        21jzele04244   3.3

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#               Name Registration Number   GPA
# 0       Ahmed Khan        21jzele04230  3.22
# 1      Fatima Noor        21jzele04231  2.15
# 2     Mohammad Ali        21jzele04232  2.74
# 3    Ayesha Siddiq        21jzele04233  3.34
# 4      Hassan Raza        21jzele04234   2.8
# 5    Zainab Sheikh        21jzele04235   2.6
# 6      Umar Farooq        21jzele04236  3.61
# 7      Maryam Bibi        21jzele04237  3.25
# 8      Bilal Saeed        21jzele04238  2.14
# 9   Khadija Rehman        21jzele04239  2.15
# 10     Yusuf Jamal        21jzele04240  2.01
# 11     Hafsa Tariq        21jzele04241  2.33
# 12    Ibrahim Zaid        21jzele04242  2.15
# 13      Nimra Shah        21jzele04243  2.07
# 14   Suleman Iqbal        21jzele04244   3.3

# %% [markdown]
# ### Pandas as pd
# Pandas is usually imported under the pd alias.
# #### alias:
# In Python alias are an alternate name for referring to the same thing.<br>
# Create an alias with the as keyword while importing:<br>
# __import pandas as pd__<br>
# Now the Pandas package can be referred to as pd instead of pandas.

# %%
import pandas as pd

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#               Name Registration Number   GPA
# 0       Ahmed Khan        21jzele04230  3.22
# 1      Fatima Noor        21jzele04231  2.15
# 2     Mohammad Ali        21jzele04232  2.74
# 3    Ayesha Siddiq        21jzele04233  3.34
# 4      Hassan Raza        21jzele04234   2.8
# 5    Zainab Sheikh        21jzele04235   2.6
# 6      Umar Farooq        21jzele04236  3.61
# 7      Maryam Bibi        21jzele04237  3.25
# 8      Bilal Saeed        21jzele04238  2.14
# 9   Khadija Rehman        21jzele04239  2.15
# 10     Yusuf Jamal        21jzele04240  2.01
# 11     Hafsa Tariq        21jzele04241  2.33
# 12    Ibrahim Zaid        21jzele04242  2.15
# 13      Nimra Shah        21jzele04243  2.07
# 14   Suleman Iqbal        21jzele04244   3.3

# %% [markdown]
# ### Checking Pandas Version
# The version string is stored under __version__ attribute.

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ## Import to CSV

# %%
df.to_csv('dataset.csv')

# %% [markdown]
# ## Remove Index

# %%
df.to_csv('pythonMondayRemoveIndex.csv', index=False)

# %% [markdown]
# ## Show some rows from the Start

# %%
df.head()
# Out:
#             Name Registration Number   GPA
# 0     Ahmed Khan        21jzele04230  3.22
# 1    Fatima Noor        21jzele04231  2.15
# 2   Mohammad Ali        21jzele04232  2.74
# 3  Ayesha Siddiq        21jzele04233  3.34
# 4    Hassan Raza        21jzele04234   2.8

# %%
df.tail(3)
# Out:
#              Name Registration Number   GPA
# 12   Ibrahim Zaid        21jzele04242  2.15
# 13     Nimra Shah        21jzele04243  2.07
# 14  Suleman Iqbal        21jzele04244   3.3

# %%
df.tail()
# Out:
#              Name Registration Number   GPA
# 10    Yusuf Jamal        21jzele04240  2.01
# 11    Hafsa Tariq        21jzele04241  2.33
# 12   Ibrahim Zaid        21jzele04242  2.15
# 13     Nimra Shah        21jzele04243  2.07
# 14  Suleman Iqbal        21jzele04244   3.3

# %%
df.describe()
# Out:
#               Name Registration Number   GPA
# count           15                  15    15
# unique          15                  15    13
# top     Ahmed Khan        21jzele04230  2.15
# freq             1                   1     3

# %%
classData = pd.read_csv("dataset.csv")
classData
# Out:
#     Unnamed: 0            Name Registration Number   GPA
# 0            0      Ahmed Khan        21jzele04230  3.22
# 11          11     Hafsa Tariq        21jzele04241  2.33
# 12          12    Ibrahim Zaid        21jzele04242  2.15
# 13          13      Nimra Shah        21jzele04243  2.07
# 14          14   Suleman Iqbal        21jzele04244  3.30

# %%
classData['GPA']
# Out:
# 0     3.22
# 1     2.15
# 2     2.74
# 3     3.34
# 4     2.80
# 5     2.60
# 6     3.61
# 7     3.25
# 8     2.14
# 9     2.15
# 10    2.01
# 11    2.33
# 12    2.15
# 13    2.07
# 14    3.30
# Name: GPA, dtype: float64

# %%
classData['Name']
# Out:
# 0         Ahmed Khan
# 1        Fatima Noor
# 2       Mohammad Ali
# 3      Ayesha Siddiq
# 4        Hassan Raza
# 5      Zainab Sheikh
# 6        Umar Farooq
# 7        Maryam Bibi
# 8        Bilal Saeed
# 9     Khadija Rehman
# 10       Yusuf Jamal
# 11       Hafsa Tariq
# 12      Ibrahim Zaid
# 13        Nimra Shah
# 14     Suleman Iqbal
# Name: Name, dtype: object

# %%
classData['Registration Number']
# Out:
# 0     21jzele04230
# 1     21jzele04231
# 2     21jzele04232
# 3     21jzele04233
# 4     21jzele04234
# 5     21jzele04235
# 6     21jzele04236
# 7     21jzele04237
# 8     21jzele04238
# 9     21jzele04239
# 10    21jzele04240
# 11    21jzele04241
# 12    21jzele04242
# 13    21jzele04243
# 14    21jzele04244
# Name: Registration Number, dtype: object

# %%
type(classData['Name'])
# Out:
# pandas.core.series.Series

# %%
classData['GPA'][0]
# Out:
# 3.22

# %%
classData['GPA'][0]=90
# Out:
# C:\Users\Abid\AppData\Local\Temp\ipykernel_5996\546375960.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData['GPA'][0]=90

# %%
classData
# Out:
#     Unnamed: 0            Name Registration Number    GPA
# 0            0      Ahmed Khan        21jzele04230  90.00
# 1            1     Fatima Noor        21jzele04231   2.15
# 2            2    Mohammad Ali        21jzele04232   2.74
# 3            3   Ayesha Siddiq        21jzele04233   3.34
# 4            4     Hassan Raza        21jzele04234   2.80
# 5            5   Zainab Sheikh        21jzele04235   2.60
# 6            6     Umar Farooq        21jzele04236   3.61
# 7            7     Maryam Bibi        21jzele04237   3.25
# 8            8     Bilal Saeed        21jzele04238   2.14
# 9            9  Khadija Rehman        21jzele04239   2.15
# 10          10     Yusuf Jamal        21jzele04240   2.01
# 11          11     Hafsa Tariq        21jzele04241   2.33
# 12          12    Ibrahim Zaid        21jzele04242   2.15
# 13          13      Nimra Shah        21jzele04243   2.07
# 14          14   Suleman Iqbal        21jzele04244   3.30

# %%
classData['GPA'][4]
# Out:
# 2.8

# %%
classData['GPA'][4]=5
# Out:
# C:\Users\Abid\AppData\Local\Temp\ipykernel_5996\590528565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData['GPA'][4]=5

# %%
classData["Registration Number"][4]="21jzele04233"
# Out:
# C:\Users\Abid\AppData\Local\Temp\ipykernel_5996\652201625.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData["Registration Number"][4]="21jzele04233"

# %%
classData
# Out:
#     Unnamed: 0            Name Registration Number    GPA
# 0            0      Ahmed Khan        21jzele04230  90.00
# 1            1     Fatima Noor        21jzele04231   2.15
# 2            2    Mohammad Ali        21jzele04232   2.74
# 3            3   Ayesha Siddiq        21jzele04233   3.34
# 4            4     Hassan Raza        21jzele04233   5.00
# 5            5   Zainab Sheikh        21jzele04235   2.60
# 6            6     Umar Farooq        21jzele04236   3.61
# 7            7     Maryam Bibi        21jzele04237   3.25
# 8            8     Bilal Saeed        21jzele04238   2.14
# 9            9  Khadija Rehman        21jzele04239   2.15
# 10          10     Yusuf Jamal        21jzele04240   2.01
# 11          11     Hafsa Tariq        21jzele04241   2.33
# 12          12    Ibrahim Zaid        21jzele04242   2.15
# 13          13      Nimra Shah        21jzele04243   2.07
# 14          14   Suleman Iqbal        21jzele04244   3.30

# %%
classData["Name"][4]
# Out:
# 'Hassan Raza'

# %%
classData
# Out:
#     Unnamed: 0            Name Registration Number    GPA
# 0            0      Ahmed Khan        21jzele04230  90.00
# 1            1     Fatima Noor        21jzele04231   2.15
# 2            2    Mohammad Ali        21jzele04232   2.74
# 3            3   Ayesha Siddiq        21jzele04233   3.34
# 4            4     Hassan Raza        21jzele04233   5.00
# 5            5   Zainab Sheikh        21jzele04235   2.60
# 6            6     Umar Farooq        21jzele04236   3.61
# 7            7     Maryam Bibi        21jzele04237   3.25
# 8            8     Bilal Saeed        21jzele04238   2.14
# 9            9  Khadija Rehman        21jzele04239   2.15
# 10          10     Yusuf Jamal        21jzele04240   2.01
# 11          11     Hafsa Tariq        21jzele04241   2.33
# 12          12    Ibrahim Zaid        21jzele04242   2.15
# 13          13      Nimra Shah        21jzele04243   2.07
# 14          14   Suleman Iqbal        21jzele04244   3.30

# %%
classData.to_csv('pythonMonday.csv')

# %%
classData.to_csv('pythonMondayRemoveIndex.csv', index=False)

# %% [markdown]
# ## Create Labels
# With the index argument, you can name your own labels.

# %%
classData.index = ["21jzele04230","21jzele04231","21jzele04232","21jzele04233","21jzele04234",
                             "21jzele04235","21jzele04236","21jzele04237","21jzele04238","21jzele04239",
                             "21jzele04240","21jzele04241","21jzele04242","21jzele04243","21jzele04244"]

# %%
classData
# Out:
#               Unnamed: 0            Name Registration Number    GPA
# 21jzele04230           0      Ahmed Khan        21jzele04230  90.00
# 21jzele04231           1     Fatima Noor        21jzele04231   2.15
# 21jzele04232           2    Mohammad Ali        21jzele04232   2.74
# 21jzele04233           3   Ayesha Siddiq        21jzele04233   3.34
# 21jzele04234           4     Hassan Raza        21jzele04233   5.00
# 21jzele04235           5   Zainab Sheikh        21jzele04235   2.60
# 21jzele04236           6     Umar Farooq        21jzele04236   3.61
# 21jzele04237           7     Maryam Bibi        21jzele04237   3.25
# 21jzele04238           8     Bilal Saeed        21jzele04238   2.14
# 21jzele04239           9  Khadija Rehman        21jzele04239   2.15
# 21jzele04240          10     Yusuf Jamal        21jzele04240   2.01
# 21jzele04241          11     Hafsa Tariq        21jzele04241   2.33
# 21jzele04242          12    Ibrahim Zaid        21jzele04242   2.15
# 21jzele04243          13      Nimra Shah        21jzele04243   2.07
# 21jzele04244          14   Suleman Iqbal        21jzele04244   3.30

# %%
classData["Name"]["21jzele04236"]
# Out:
# 'Umar Farooq'

# %% [markdown]
# ## Pandas
# Pandas is an open source data analysis library written in Python.<br>
# It uses the power and speed of numpy to make data analysis and preprocessing easy for data scientists.<br>
# __Pandas__ is used to analyze data.<br>
# Python data analysis using pandas is a great start to Exploratory Data Analysis (EDA) for a data scientist.

# %% [markdown]
# ## Pandas Data Structure
# Panda has two types of Data Structure:<br>
#     a) Series<br>
#     b) Dataframe
# ### Series
# It is a one dimentional array with indexes. It stores a single column or row of data in a Dataframe.<br>
# It is a one dimensional array capable of holding any type of data.
# ### Dataframe
# It is a tabular spreadsheet like structure representing rows each of which contains one or more columns.<br>
# It is a multi dimensional array capable of holding any type of data.<br>
# __Series__ is like a column, a __DataFrame__ is the whole table.

# %%
classData['GPA']
# Out:
# 21jzele04230    90.00
# 21jzele04231     2.15
# 21jzele04232     2.74
# 21jzele04233     3.34
# 21jzele04234     5.00
# 21jzele04235     2.60
# 21jzele04236     3.61
# 21jzele04237     3.25
# 21jzele04238     2.14
# 21jzele04239     2.15
# 21jzele04240     2.01
# 21jzele04241     2.33
# 21jzele04242     2.15
# 21jzele04243     2.07
# 21jzele04244     3.30
# Name: GPA, dtype: float64

# %%
type(classData['GPA'])
# Out:
# pandas.core.series.Series

# %%
classData
# Out:
#               Unnamed: 0            Name Registration Number    GPA
# 21jzele04230           0      Ahmed Khan        21jzele04230  90.00
# 21jzele04231           1     Fatima Noor        21jzele04231   2.15
# 21jzele04232           2    Mohammad Ali        21jzele04232   2.74
# 21jzele04233           3   Ayesha Siddiq        21jzele04233   3.34
# 21jzele04234           4     Hassan Raza        21jzele04233   5.00
# 21jzele04235           5   Zainab Sheikh        21jzele04235   2.60
# 21jzele04236           6     Umar Farooq        21jzele04236   3.61
# 21jzele04237           7     Maryam Bibi        21jzele04237   3.25
# 21jzele04238           8     Bilal Saeed        21jzele04238   2.14
# 21jzele04239           9  Khadija Rehman        21jzele04239   2.15
# 21jzele04240          10     Yusuf Jamal        21jzele04240   2.01
# 21jzele04241          11     Hafsa Tariq        21jzele04241   2.33
# 21jzele04242          12    Ibrahim Zaid        21jzele04242   2.15
# 21jzele04243          13      Nimra Shah        21jzele04243   2.07
# 21jzele04244          14   Suleman Iqbal        21jzele04244   3.30

# %%
type(classData)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np

# %%
series1= pd.Series(np.random.rand())

# %%
series1
# Out:
# 0    0.991585
# dtype: float64

# %%
series1= pd.Series(np.random.rand(30))

# %%
series1
# Out:
# 0     0.287346
# 1     0.496483
# 2     0.193062
# 3     0.879986
# 4     0.300041
# 5     0.554982
# 6     0.125486
# 7     0.853949
# 8     0.707461
# 9     0.100301
# 10    0.800793
# 11    0.782742
# 12    0.622870
# 13    0.312172
# 14    0.373158
# 15    0.859227
# 16    0.748967
# 17    0.193799
# 18    0.886094
# 19    0.251864
# 20    0.356823
# 21    0.602636
# 22    0.293723
# 23    0.768777
# 24    0.224142
# 25    0.533453
# 26    0.256550
# 27    0.255009
# 28    0.941606
# 29    0.205038
# dtype: float64

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
newDf = pd.DataFrame(np.random.rand(330,5))
# newDf = pd.DataFrame(np.random.rand(330,5), index=np.arange(330))

# %%
type(newDf)
# Out:
# pandas.core.frame.DataFrame

# %%
newDf
# Out:
#             0         1         2         3         4
# 0    0.815599  0.401892  0.948678  0.460091  0.201548
# 1    0.023945  0.496761  0.565105  0.745769  0.547501
# 2    0.384086  0.379255  0.054014  0.159341  0.850943
# 3    0.892627  0.801672  0.501838  0.266774  0.254969
# 4    0.360198  0.452141  0.143943  0.480502  0.463038
# ..        ...       ...       ...       ...       ...
# 325  0.442365  0.703879  0.409628  0.320831  0.798490
# 326  0.426388  0.205195  0.368737  0.197093  0.604967
# 327  0.274447  0.902796  0.182804  0.852963  0.057220
# 328  0.284391  0.124291  0.660335  0.329036  0.439533
# 329  0.073319  0.934033  0.059327  0.218147  0.317663
#
# [330 rows x 5 columns]

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0  0.815599  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501

# %%
newDf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newDf.tail(2)
# Out:
#             0         1         2         3         4
# 328  0.284391  0.124291  0.660335  0.329036  0.439533
# 329  0.073319  0.934033  0.059327  0.218147  0.317663

# %%
newDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       330 non-null    float64
#  1   1       330 non-null    float64
#  2   2       330 non-null    float64
#  3   3       330 non-null    float64
#  4   4       330 non-null    float64
# dtypes: float64(5)
# memory usage: 13.0 KB

# %%
newDf.describe()
# Out:
#                 0           1           2           3           4
# count  330.000000  330.000000  330.000000  330.000000  330.000000
# mean     0.494335    0.524731    0.513212    0.514359    0.509134
# std      0.287989    0.286077    0.295396    0.283560    0.292338
# min      0.000540    0.002204    0.001025    0.002025    0.002919
# 25%      0.249449    0.274446    0.245258    0.277492    0.255903
# 50%      0.489215    0.540179    0.524810    0.509135    0.520123
# 75%      0.749189    0.775917    0.766970    0.782853    0.770869
# max      0.999521    0.999595    0.998664    0.999503    0.998850

# %%
newDf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newDf[0][0]= "Maaz Khan"
# Out:
# C:\Users\Abid\AppData\Local\Temp\ipykernel_5996\4095004716.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDf[0][0]= "Maaz Khan"
# C:\Users\Abid\AppData\Local\Temp\ipykernel_5996\4095004716.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Maaz Khan' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newDf[0][0]= "Maaz Khan"

# %%
newDf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newDf
# Out:
#              0         1         2         3         4
# 0    Maaz Khan  0.401892  0.948678  0.460091  0.201548
# 1     0.023945  0.496761  0.565105  0.745769  0.547501
# 2     0.384086  0.379255  0.054014  0.159341  0.850943
# 3     0.892627  0.801672  0.501838  0.266774  0.254969
# 4     0.360198  0.452141  0.143943  0.480502  0.463038
# ..         ...       ...       ...       ...       ...
# 325   0.442365  0.703879  0.409628  0.320831  0.798490
# 326   0.426388  0.205195  0.368737  0.197093  0.604967
# 327   0.274447  0.902796  0.182804  0.852963  0.057220
# 328   0.284391  0.124291  0.660335  0.329036  0.439533
# 329   0.073319  0.934033  0.059327  0.218147  0.317663
#
# [330 rows x 5 columns]

# %%
newDf.index
# Out:
# RangeIndex(start=0, stop=330, step=1)

# %%
newDf.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# 329  0.073319  0.934033  0.059327  0.218147  0.317663
#
# [330 rows x 5 columns]

# %% [markdown]
# ## view

# %%
newDfView=newDf

# %%
newDfView
# Out:
#             0         1         2         3         4
# 0         0.3  0.401892  0.948678  0.460091  0.201548
# 1    0.023945  0.496761  0.565105  0.745769  0.547501
# 2    0.384086  0.379255  0.054014  0.159341  0.850943
# 3    0.892627  0.801672  0.501838  0.266774  0.254969
# 4    0.360198  0.452141  0.143943  0.480502  0.463038
# ..        ...       ...       ...       ...       ...
# 325  0.442365  0.703879  0.409628  0.320831  0.798490
# 326  0.426388  0.205195  0.368737  0.197093  0.604967
# 327  0.274447  0.902796  0.182804  0.852963  0.057220
# 328  0.284391  0.124291  0.660335  0.329036  0.439533
# 329  0.073319  0.934033  0.059327  0.218147  0.317663
#
# [330 rows x 5 columns]

# %%
newDfView[0][0]=765
# Out:
# C:\Users\Abid\AppData\Local\Temp\ipykernel_5996\4063526219.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDfView[0][0]=765
# C:\Users\Abid\AppData\Local\Temp\ipykernel_5996\4063526219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDfView[0][0]=765

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0       765  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501
# 2  0.384086  0.379255  0.054014  0.159341  0.850943
# 3  0.892627  0.801672  0.501838  0.266774  0.254969
# 4  0.360198  0.452141  0.143943  0.480502  0.463038

# %%
newDfView.head()
# Out:
#           0         1         2         3         4
# 0       765  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501
# 2  0.384086  0.379255  0.054014  0.159341  0.850943
# 3  0.892627  0.801672  0.501838  0.266774  0.254969
# 4  0.360198  0.452141  0.143943  0.480502  0.463038

# %%
newDfCopy=newDf.copy()

# %%
newDfCopy[0][0]=656
# Out:
# C:\Users\Abid\AppData\Local\Temp\ipykernel_5996\2532441962.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDfCopy[0][0]=656
# C:\Users\Abid\AppData\Local\Temp\ipykernel_5996\2532441962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDfCopy[0][0]=656

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0       765  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501
# 2  0.384086  0.379255  0.054014  0.159341  0.850943
# 3  0.892627  0.801672  0.501838  0.266774  0.254969
# 4  0.360198  0.452141  0.143943  0.480502  0.463038

# %%
newDfCopy.head()
# Out:
#           0         1         2         3         4
# 0       656  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501
# 2  0.384086  0.379255  0.054014  0.159341  0.850943
# 3  0.892627  0.801672  0.501838  0.266774  0.254969
# 4  0.360198  0.452141  0.143943  0.480502  0.463038

# %% [markdown]
# ## loc

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0       765  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501

# %%
newDf.loc[0,0]
# Out:
# 765

# %%
newDf.loc[0,0]=5678

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0      5678  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501

# %%
newDf.loc[0,4]
# Out:
# 0.20154791283572215

# %%
newDf.loc[325,1]
# Out:
# 0.7038787287774729

# %%
newDf.loc[0,0]=9875

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0      9875  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501

# %%
newDf.columns=list("ABCDE")

# %%
newDf.head(3)
# Out:
#           A         B         C         D         E
# 0      9875  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501
# 2  0.384086  0.379255  0.054014  0.159341  0.850943

# %%
newDf.loc[0, "A"]
# Out:
# 9875

# %%
newDf.loc[0,"A"]=65

# %%
newDf.head(3)
# Out:
#           A         B         C         D         E
# 0        65  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501
# 2  0.384086  0.379255  0.054014  0.159341  0.850943

# %%
newDf.loc[35,"A"]
# Out:
# 0.000540190008987973

# %%
newDf.drop(0, axis=0).head(3)
# Out:
#           A         B         C         D         E
# 1  0.023945  0.496761  0.565105  0.745769  0.547501
# 2  0.384086  0.379255  0.054014  0.159341  0.850943
# 3  0.892627  0.801672  0.501838  0.266774  0.254969

# %%
newDf.drop("A", axis=1).head(3)
# Out:
#           B         C         D         E
# 0  0.401892  0.948678  0.460091  0.201548
# 1  0.496761  0.565105  0.745769  0.547501
# 2  0.379255  0.054014  0.159341  0.850943

# %%
newDf.head(3)
# Out:
#           A         B         C         D         E
# 0        65  0.401892  0.948678  0.460091  0.201548
# 1  0.023945  0.496761  0.565105  0.745769  0.547501
# 2  0.384086  0.379255  0.054014  0.159341  0.850943

# %%
newDf = newDf.drop("A", axis=1)

# %%
newDf.head(3)
# Out:
#           B         C         D         E
# 0  0.401892  0.948678  0.460091  0.201548
# 1  0.496761  0.565105  0.745769  0.547501
# 2  0.379255  0.054014  0.159341  0.850943

# %%
newDf.loc[[1,2],["C","D"]]
# Out:
#           C         D
# 1  0.565105  0.745769
# 2  0.054014  0.159341

# %%
newDf.head(3)
# Out:
#           B         C         D         E
# 0  0.401892  0.948678  0.460091  0.201548
# 1  0.496761  0.565105  0.745769  0.547501
# 2  0.379255  0.054014  0.159341  0.850943

# %%
newDf.loc[:,["C","D"]]
# Out:
#             C         D
# 0    0.948678  0.460091
# 1    0.565105  0.745769
# 2    0.054014  0.159341
# 3    0.501838  0.266774
# 4    0.143943  0.480502
# ..        ...       ...
# 325  0.409628  0.320831
# 326  0.368737  0.197093
# 327  0.182804  0.852963
# 328  0.660335  0.329036
# 329  0.059327  0.218147
#
# [330 rows x 2 columns]

# %%
newDf.loc[[1,2],:]
# Out:
#           B         C         D         E
# 1  0.496761  0.565105  0.745769  0.547501
# 2  0.379255  0.054014  0.159341  0.850943

# %%
newDf.loc[:5,["C","D"]]
# Out:
#           C         D
# 0  0.948678  0.460091
# 1  0.565105  0.745769
# 2  0.054014  0.159341
# 3  0.501838  0.266774
# 4  0.143943  0.480502
# 5  0.982169  0.886981

# %%
newDf.loc[[1,2],:"D"]
# Out:
#           B         C         D
# 1  0.496761  0.565105  0.745769
# 2  0.379255  0.054014  0.159341

# %%
newDf.loc[(newDf["B"]<0.3)]
# Out:
#             B         C         D         E
# 10   0.244565  0.846726  0.246749  0.192691
# 13   0.012311  0.393031  0.047376  0.563338
# 23   0.161497  0.649145  0.117549  0.569003
# 24   0.182491  0.676852  0.515971  0.236886
# 26   0.121418  0.615695  0.031721  0.250131
# ..        ...       ...       ...       ...
# 310  0.082676  0.851663  0.852455  0.668739
# 311  0.122564  0.237748  0.321796  0.003549
# 317  0.249611  0.570271  0.991796  0.786249
# 326  0.205195  0.368737  0.197093  0.604967
# 328  0.124291  0.660335  0.329036  0.439533
#
# [88 rows x 4 columns]

# %%
newDf.loc[(newDf["B"]<0.3) & (newDf["D"]>0.2)]
# Out:
#             B         C         D         E
# 10   0.244565  0.846726  0.246749  0.192691
# 24   0.182491  0.676852  0.515971  0.236886
# 35   0.188852  0.558266  0.226942  0.951170
# 41   0.190323  0.664924  0.556703  0.842561
# 42   0.249895  0.361373  0.340667  0.260082
# ..        ...       ...       ...       ...
# 291  0.030357  0.567617  0.605289  0.810639
# 310  0.082676  0.851663  0.852455  0.668739
# 311  0.122564  0.237748  0.321796  0.003549
# 317  0.249611  0.570271  0.991796  0.786249
# 328  0.124291  0.660335  0.329036  0.439533
#
# [72 rows x 4 columns]

# %%
newDf.head(3)
# Out:
#           B         C         D         E
# 0  0.401892  0.948678  0.460091  0.201548
# 1  0.496761  0.565105  0.745769  0.547501
# 2  0.379255  0.054014  0.159341  0.850943

# %% [markdown]
# ## iloc

# %%
newDf.iloc[0,0]
# Out:
# 0.40189227096998037

# %%
newDf.iloc[0,0]=555

# %%
newDf.head()
# Out:
#             B         C         D         E
# 0  555.000000  0.948678  0.460091  0.201548
# 1    0.496761  0.565105  0.745769  0.547501
# 2    0.379255  0.054014  0.159341  0.850943
# 3    0.801672  0.501838  0.266774  0.254969
# 4    0.452141  0.143943  0.480502  0.463038

# %%
newDf.iloc[[0,4],[1,3]]
# Out:
#           C         E
# 0  0.948678  0.201548
# 4  0.143943  0.463038

# %%
newDf.head(4)
# Out:
#             B         C         D         E
# 0  555.000000  0.948678  0.460091  0.201548
# 1    0.496761  0.565105  0.745769  0.547501
# 2    0.379255  0.054014  0.159341  0.850943
# 3    0.801672  0.501838  0.266774  0.254969

# %%
newDf.drop(0).head()
# Out:
#           B         C         D         E
# 1  0.496761  0.565105  0.745769  0.547501
# 2  0.379255  0.054014  0.159341  0.850943
# 3  0.801672  0.501838  0.266774  0.254969
# 4  0.452141  0.143943  0.480502  0.463038
# 5  0.637598  0.982169  0.886981  0.791938

# %%
# newDf.drop(0, axis=1)

# %%
# newDf.drop("B", axis=1).head()

# %%
newDf.drop(["C", "D"], axis=1).head()
# Out:
#             B         E
# 0  555.000000  0.201548
# 1    0.496761  0.547501
# 2    0.379255  0.850943
# 3    0.801672  0.254969
# 4    0.452141  0.463038

# %%
newDf.head()
# Out:
#             B         C         D         E
# 0  555.000000  0.948678  0.460091  0.201548
# 1    0.496761  0.565105  0.745769  0.547501
# 2    0.379255  0.054014  0.159341  0.850943
# 3    0.801672  0.501838  0.266774  0.254969
# 4    0.452141  0.143943  0.480502  0.463038

# %%
newDf.drop(['B', 'D'], axis=1, inplace=True)

# %%
newDf.head()
# Out:
#           C         E
# 0  0.948678  0.201548
# 1  0.565105  0.547501
# 2  0.054014  0.850943
# 3  0.501838  0.254969
# 4  0.143943  0.463038

# %%
newDf.reset_index().head()
# Out:
#    index         C         E
# 0      0  0.948678  0.201548
# 1      1  0.565105  0.547501
# 2      2  0.054014  0.850943
# 3      3  0.501838  0.254969
# 4      4  0.143943  0.463038

# %%
newDf.reset_index(drop=True).head()
# Out:
#           C         E
# 0  0.948678  0.201548
# 1  0.565105  0.547501
# 2  0.054014  0.850943
# 3  0.501838  0.254969
# 4  0.143943  0.463038

# %%
newDf.head()
# Out:
#           C         E
# 0  0.948678  0.201548
# 1  0.565105  0.547501
# 2  0.054014  0.850943
# 3  0.501838  0.254969
# 4  0.143943  0.463038

# %%
newDf.reset_index(drop=True, inplace=True)

# %%
newDf.head()
# Out:
#           C         E
# 0  0.948678  0.201548
# 1  0.565105  0.547501
# 2  0.054014  0.850943
# 3  0.501838  0.254969
# 4  0.143943  0.463038

# %% [markdown]
# # Groupby
# The groupby method allows you to group rows of data together and call aggregate functions
#
# ​
# ​

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ### Now you can use the .groupby() method to group rows together based off of a column name.
# For instance let's group based off of Company. This will create a DataFrameGroupBy object:

# %%
df.groupby('Company')

# %% [markdown]
# ##### You can save this object as a new variable:

# %%
by_comp = df.groupby("Company")
type(by_comp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# #### And then call aggregate methods of the object:

# %%
by_comp.mean("sale")
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df.groupby("Company")

# %%
df.select_dtypes(include='number').groupby(df['Company']).std()
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0
